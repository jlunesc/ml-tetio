# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tl-data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40790 entries, 0 to 40789
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           40790 non-null  object
#  1   username     40790 non-null  object
#  2   gamesplayed  40790 non-null  int64
#  3   gameswon     40790 non-null  int64
#  4   tr           40790 non-null  float64
#  5   glicko       40790 non-null  float64
#  6   rd           40790 non-null  float64
#  7   rank         40790 non-null  object
#  8   apm          40790 non-null  float64
#  9   pps          40790 non-null  float64
#  10  vs           40790 non-null  float64
#  11  verified     40790 non-null  bool
#  12  40l_sprint   36475 non-null  float64
#  13  blitz        31858 non-null  float64
# dtypes: bool(1), float64(8), int64(2), object(3)
# memory usage: 4.1+ MB

# %%
df.hist(figsize=(10,10),bins=10)
plt.show()
